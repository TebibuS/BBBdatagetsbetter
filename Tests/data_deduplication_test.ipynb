# %%
#importing necessary packages
import pandas as pd
import recordlinkage
import pathlib

# %% [markdown]
# # Loading Data
# The pre-processed bussniess record data is fed into the script using the load_data function. This data is then preprocessed further by ensuring correct data typing of the firm ID and the phone number and by creating a unique primary key called "ID".

# %%
#Read cleaned data into dataframe
Data_folder: str = pathlib.Path('C:\BBBdatagetsbetter\Data\cleaned_and_normalized_data_all.csv')
record_data = pd.read_csv(Data_folder)
record_data['firm_id'] = record_data['firm_id'].astype(str)
record_data['phone'] = record_data['phone'].astype(str)
record_data = record_data.reset_index(names=['ID'])
record_data
# Out:
#             ID       firm_id                          company_name  \
# 0            0           2.0                      Able Fence, Inc.
# 1            1           5.0                          Albin Chapel
# 2            2           5.0              Albin Funeral Chapel Inc
# 3            3           5.0                  Albin Endeavor, Inc.
# 4            4           7.0                      Albrecht Company
# ...        ...           ...                                   ...
# 184721  184721  1000067470.0          Just Right Building Services
# 184722  184722  1000067471.0  Devils Lake Marine and Sports Center
# 184723  184723  1000067472.0   Beautiful Day Counseling Center LLC
# 184724  184724  1000067473.0          Everybody Healing Center LLC
# 184725  184725  1000067474.0                  Cannon Valley Moving
#
#                        address           city state      zip         phone  \
# 0                78 Acker St E     Saint Paul    MN  55117.0  6512227737.0
# 1            2200 Nicollet Ave    Minneapolis    MN  55404.0           nan
# 2              6855 Rowland Rd   Eden Prairie    MN  55344.0  6128711418.0
# 3                 PO Box 46147   Eden Prairie    MN  55344.0  9529140043.0
# 4         1408 County Road C W      Roseville    MN  55113.0  6516334510.0
# ...                        ...            ...   ...      ...           ...
# 184721        7283 Mallard Rd      Brook Park    MN  55007.0           nan
# 184722        1410 Kelly Dr NW    Devils Lake    ND  58301.0  7016621044.0
# 184723  300 3rd Ave SE Ste 408      Rochester    MN  55904.0  5072084150.0
# 184724  8085 Wayzata Blvd  #10  Golden Valley    MN  55426.0  6125672270.0
# 184725            P.O. Box 481   Cannon Falls    MN  55009.0  6513610688.0
#
#                                      email  \
# 0                afinc1008@qwestoffice.net
# 1                   office@albinchapel.com
# 2                    jimalbinson@gmail.com
# 3                                      NaN
# 4                 mail@albrechtcompany.com
# ...                                    ...
# 184721                                 NaN
# 184722                                 NaN
# 184723  caitlin@beautifuldaycounseling.com
# 184724                                 NaN
# 184725                                 NaN
#
#                                             url
# 0                                           NaN
# 1                   http://www.albinchapel.com/
# 2                                           NaN
# 3                                           NaN
# 4              https://www.albrechtcompany.com/
# ...                                         ...
# 184721                                      NaN
# 184722        https://www.devilslakemarine.com/
# 184723  https://www.beautifuldaycounseling.com/
# 184724                                      NaN
# 184725           https://cannonvalleymoving.com
#
# [184726 rows x 10 columns]

# %% [markdown]
# # Indexing Records
# All possible duplicate record pairs are created using a blocking method which divides the records in such a way where the records within each group have a high likelihood of being duplicate records. These duplicate record pairs are known as candidate links.

# %%
#Setup indexer to make candiate pairs of records within the dataset. Block candiate pair generation on records that have
#valid condensed names. A data sample of 100000 is used for computing constraints. 
indexer = recordlinkage.Index()
data_sample = record_data
indexer.block("company_name")
indexer.block("address")
canidate_links = indexer.index(data_sample)
print(len(data_sample), len(canidate_links))
# Out:
# 184726 116938

# %% [markdown]
# # Computing Similarity Score based on features
#
#  Each candidate link is evaluated based on their simiarlity of company name, address, state, email, and url. These candidate links are then ranked to determine the best matches using a threshold

# %%
"""
Setup comparision methods used to determine potential records that match. Comparision methods can either be
Numeric, string-based, or exact matches. Specific comparrsion methods are a work in progress to determine which
features/methods are the best for generating accurate matches. 
"""
compare_cl = recordlinkage.Compare()
#compare_cl.string("condensed_name", "condensed_name",method ="levenshtein",threshold=0.75, label="condensed_name")
compare_cl.string(
    "company_name", "company_name", method="levenshtein", threshold=0.75, label="company_name"
)
compare_cl.string("address", "address", method="levenshtein", threshold=0.85, label="address_1")
compare_cl.exact("state", "state", label="state")
compare_cl.string(
    "email", "email", method="levenshtein", threshold=0.85, label="email"
)
compare_cl.string(
    "url", "url", label = "url"
)
# Computes the matching score of each record based on the candiate links generated and the comparision criteria. 
features = compare_cl.compute(canidate_links, data_sample)

# %% [markdown]
# As shown below, the similarity score of the matched record pair is computed for each record fair. The value represents a percentage match of each feature.

# %%
features.head(10)
# Out:
#            company_name  address_1  state  email       url
# 12   11             0.0        1.0      1    0.0  0.787234
# 134  133            0.0        1.0      1    0.0  0.000000
# 135  131            0.0        1.0      1    0.0  0.000000
# 494  493            0.0        1.0      1    0.0  0.000000
# 778  708            1.0        0.0      0    0.0  0.000000
# 856  747            0.0        1.0      1    0.0  0.000000
# 1257 1036           0.0        1.0      1    0.0  0.000000
# 1297 1296           0.0        1.0      1    0.0  0.000000
# 1310 1309           1.0        1.0      1    0.0  0.000000
# 1349 27             1.0        1.0      1    0.0  0.000000

# %% [markdown]
# Below is a count of all the matched records obtained through the data indexing and feature comparrision process. Each pair has a total match value which shows how likely the record pair is a duplicate record.

# %%
#Finds the similarity score of overall records which is based on the sum of each feature being matched.
round(features.sum(axis=1)).value_counts().sort_index(ascending=False)
# Out:
# 5.0       31
# 4.0    21467
# 3.0    15813
# 2.0    64365
# 1.0    15262
# dtype: int64

# %%
#Potential matches are extracted from the features based on an arbirtray score of 3.5.
matches = features[round(features.sum(axis=1)) >= 4.5]
matches
# Out:
#                company_name  address_1  state  email       url
# 31626  12001            1.0        1.0      1    1.0  1.000000
# 53160  53159            1.0        1.0      1    1.0  1.000000
# 59684  56086            1.0        1.0      1    1.0  0.939394
# 70393  22224            1.0        1.0      1    1.0  0.956522
# 75674  75152            1.0        1.0      1    1.0  1.000000
# 75700  75152            1.0        1.0      1    1.0  1.000000
# 82542  80097            1.0        1.0      1    1.0  0.965517
# 106751 86209            1.0        1.0      1    1.0  0.866667
# 110522 11005            1.0        1.0      1    1.0  0.571429
# 125281 125276           1.0        1.0      1    1.0  1.000000
# 127010 127006           1.0        1.0      1    1.0  1.000000
# 133137 8212             1.0        1.0      1    1.0  0.814815
# 141416 141415           1.0        1.0      1    1.0  1.000000
# 141675 69366            1.0        1.0      1    1.0  0.952381
# 144846 140358           1.0        1.0      1    1.0  1.000000
# 147686 138190           1.0        1.0      1    1.0  1.000000
# 148629 100240           1.0        1.0      1    1.0  0.866667
# 157752 85583            1.0        1.0      1    1.0  1.000000
# 161732 161730           1.0        1.0      1    1.0  1.000000
# 161750 161744           1.0        1.0      1    1.0  1.000000
# 161752 161751           1.0        1.0      1    1.0  1.000000
# 162348 162347           1.0        1.0      1    1.0  1.000000
# 162479 162472           1.0        1.0      1    1.0  1.000000
# 162535 162427           1.0        1.0      1    1.0  1.000000
# 162546 162544           1.0        1.0      1    1.0  1.000000
# 168463 167128           1.0        1.0      1    1.0  0.931034
# 170489 170320           1.0        1.0      1    1.0  1.000000
# 172288 172286           1.0        1.0      1    1.0  1.000000
# 172291 172287           1.0        1.0      1    1.0  1.000000
# 173551 173550           1.0        1.0      1    1.0  1.000000
# 176313 83040            1.0        1.0      1    1.0  0.972222

# %% [markdown]
# Each pair is given a unique ID to be used for obtaining the firm id for each record

# %%
#The pairs of potential records are given IDs to be used for creating the final output
matches = matches.reset_index(names=['ID1','ID2'])
matches
# Out:
#        ID1     ID2  company_name  address_1  state  email       url
# 0    31626   12001           1.0        1.0      1    1.0  1.000000
# 1    53160   53159           1.0        1.0      1    1.0  1.000000
# 2    59684   56086           1.0        1.0      1    1.0  0.939394
# 3    70393   22224           1.0        1.0      1    1.0  0.956522
# 4    75674   75152           1.0        1.0      1    1.0  1.000000
# 5    75700   75152           1.0        1.0      1    1.0  1.000000
# 6    82542   80097           1.0        1.0      1    1.0  0.965517
# 7   106751   86209           1.0        1.0      1    1.0  0.866667
# 8   110522   11005           1.0        1.0      1    1.0  0.571429
# 9   125281  125276           1.0        1.0      1    1.0  1.000000
# 10  127010  127006           1.0        1.0      1    1.0  1.000000
# 11  133137    8212           1.0        1.0      1    1.0  0.814815
# 12  141416  141415           1.0        1.0      1    1.0  1.000000
# 13  141675   69366           1.0        1.0      1    1.0  0.952381
# 14  144846  140358           1.0        1.0      1    1.0  1.000000
# 15  147686  138190           1.0        1.0      1    1.0  1.000000
# 16  148629  100240           1.0        1.0      1    1.0  0.866667
# 17  157752   85583           1.0        1.0      1    1.0  1.000000
# 18  161732  161730           1.0        1.0      1    1.0  1.000000
# 19  161750  161744           1.0        1.0      1    1.0  1.000000
# 20  161752  161751           1.0        1.0      1    1.0  1.000000
# 21  162348  162347           1.0        1.0      1    1.0  1.000000
# 22  162479  162472           1.0        1.0      1    1.0  1.000000
# 23  162535  162427           1.0        1.0      1    1.0  1.000000
# 24  162546  162544           1.0        1.0      1    1.0  1.000000
# 25  168463  167128           1.0        1.0      1    1.0  0.931034
# 26  170489  170320           1.0        1.0      1    1.0  1.000000
# 27  172288  172286           1.0        1.0      1    1.0  1.000000
# 28  172291  172287           1.0        1.0      1    1.0  1.000000
# 29  173551  173550           1.0        1.0      1    1.0  1.000000
# 30  176313   83040           1.0        1.0      1    1.0  0.972222

# %% [markdown]
# # Identifying Duplicate Records
# Using the unique "ID" of each paired record, the firm ID is extracted and placed into a list of tuples to identify

# %%
def get_matches(data: pd.DataFrame, matches: pd.DataFrame) -> list:
    """
    Get matched 'firm_id' pairs.

    Args:
        data (pd.DataFrame): DataFrame containing the data.
        matches (pd.DataFrame): DataFrame containing matched record pairs.

    Returns:
        list: List of tuples containing matched 'firm_id' pairs.
    """
    def get_firm_id(id_list):
        temp = []
        for id in id_list:
            row = data[data['ID'] == id]
            firm_id = row.iloc[0]['firm_id']
            temp.append(firm_id)
        return temp
    
    id_list1 = matches.ID1.tolist()
    id_list2 = matches.ID2.tolist()
    list1 = get_firm_id(id_list1)
    list2 = get_firm_id(id_list2)
    matches_tuple = [(x, y) for x, y in zip(list1, list2)]
    return matches_tuple

# %%
results = get_matches(record_data,matches)
results
# Out:
# [('96016442.0', '21004636.0'),
#  ('96099993.0', '96099992.0'),
#  ('96123517.0', '96112007.0'),
#  ('96146766.0', '96000350.0'),
#  ('96159974.0', '96158896.0'),
#  ('96160022.0', '96158896.0'),
#  ('96204963.0', '96181169.0'),
#  ('96502396.0', '96249102.0'),
#  ('96540988.0', '20001775.0'),
#  ('96569281.0', '96569277.0'),
#  ('96572615.0', '96572613.0'),
#  ('1000002172.0', '11003071.0'),
#  ('1000010135.0', '1000010134.0'),
#  ('1000010364.0', '96143934.0'),
#  ('1000013103.0', '1000009127.0'),
#  ('1000015515.0', '1000007231.0'),
#  ('1000016258.0', '96369208.0'),
#  ('1000027057.0', '96236263.0'),
#  ('1000035178.0', '1000035176.0'),
#  ('1000035191.0', '1000035190.0'),
#  ('1000035193.0', '1000035192.0'),
#  ('1000035799.0', '1000035798.0'),
#  ('1000035940.0', '1000035933.0'),
#  ('1000035996.0', '1000035888.0'),
#  ('1000036007.0', '1000036005.0'),
#  ('1000045842.0', '1000044797.0'),
#  ('1000048532.0', '1000048388.0'),
#  ('96114600.0', '96114504.0'),
#  ('96114576.0', '96114546.0'),
#  ('1000054087.0', '1000054086.0'),
#  ('1000057576.0', '96210127.0')]

# %% [markdown]
# # Test Functions
# Get

# %%
#Returns the values of a specific column in a Dataframe
def getColumnValues(df, column_name: str) -> list[str]:
    return df[column_name]

# %%
#Retrieves records from a DataFrame based on the values in a specified ID column.
def getRecordsByID(df, ID_Column_header: str) -> list[str]:
    #Gets values from a specific column based on the column name
    column_values = getColumnValues(df, ID_Column_header)
    #Intializes a list based on all the column headers that were in the orginal record_data
    record_list = [record_data.columns.values.tolist()]
    #For every record in the column, find the corresponding record in the record_data and append its information
    #into the record_list
    for value in column_values:
        row = record_data[record_data['ID'] == value]
        record_list.append(row.values.tolist())
    return record_list

# %%
#Gets a list of record information from the record_data dataframe of the records that were in the matches dataframe
ID_list1 = getRecordsByID(matches,"ID1")
ID_list2 = getRecordsByID(matches,"ID2")

# %%
ID_list1
# Out:
# [['ID',
#   'firm_id',
#   'company_name',
#   'address',
#   'city',
#   'state',
#   'zip',
#   'phone',
#   'email',
#   'url'],
#  [[31626,
#    '96016442.0',
#    'Boyton Health Services',
#    '410 Church St SE',
#    'Minneapolis',
#    'MN',
#    55455.0,
#    '6126258400.0',
#    'canderson@bhs.umn.edu',
#    'http://www.bhs.umn.edu']],
#  [[53160,
#    '96099993.0',
#    'Red Wing Housing and Redevelopment Authority',
#    '428 W 5th St',
#    'Red Wing',
#    'MN',
#    55066.0,
#    '6513850551.0',
#    'randal.hemmerlin@ci.red-wing.mn.us',
#    'http://www.redwinghra.org']],
#  [[59684,
#    '96123517.0',
#    'Pinnacle Services Inc',
#    '724 Central Ave NE',
#    'Minneapolis',
#    'MN',
#    55414.0,
#    '6129773100.0',
#    'nicolas.thomley@pinnacleservices.org',
#    'http://www.pinnacleservices.org']],
#  [[70393,
#    '96146766.0',
#    'Talberg Lawn Landscape',
#    '11770 Justen Cir',
#    'Osseo',
#    'MN',
#    55369.0,
#    '7634283550.0',
#    'nfo@talberg.com',
#    'http://www.talberg.com']],
#  [[75674,
#    '96159974.0',
#    'Westside Liquor of Waite Park, Inc',
#    '8585 NE River Rd',
#    'Rice',
#    'MN',
#    56367.0,
#    '3202539511.0',
#    'mholte@westsideliquor.com',
#    'https://facebook.com/westsideliquormn']],
#  [[75700,
#    '96160022.0',
#    'Westside Liquor of Rice, Inc.',
#    '8585 NE River Rd',
#    'Rice',
#    'MN',
#    56367.0,
#    '3203934513.0',
#    'mholte@westsideliquor.com',
#    'https://facebook.com/westsideliquormn']],
#  [[82542,
#    '96204963.0',
#    'Homeopathic Medical Clinic, PA',
#    '4201 Excelsior Blvd',
#    'Minneapolis',
#    'MN',
#    55416.0,
#    '9529338900.0',
#    'jmirman@demystify.com',
#    'http://www.bookonhealing.com']],
#  [[106751,
#    '96502396.0',
#    'Arend Remodeling, LLC',
#    '1301 Cannon Ave',
#    'Mounds View',
#    'MN',
#    55112.0,
#    'nan',
#    'mark.arend@usfamily.net',
#    'http://www.arendremodeling.com']],
#  [[110522,
#    '96540988.0',
#    '7O2 Communications',
#    '702 Main Ave',
#    'Moorhead',
#    'MN',
#    56560.0,
#    '2182275166.0',
#    '702@702com.net',
#    'https://702com.net/']],
#  [[125281,
#    '96569281.0',
#    'Forman Market Incorporated',
#    '108 S Cascade St',
#    'Fergus Falls',
#    'MN',
#    56537.0,
#    '2189984330.0',
#    'rickell@fintegra.net',
#    'http://www.richardell.com']],
#  [[127010,
#    '96572615.0',
#    'Cherry Creek Water LLC',
#    '502 3rd St NW',
#    'Watford City',
#    'ND',
#    58854.0,
#    '7018426525.0',
#    'info@CitadelEP.com',
#    'http://www.citadelep.com']],
#  [[133137,
#    '1000002172.0',
#    'Vision Tree Service',
#    '895 Ivy Ave E',
#    'Saint Paul',
#    'MN',
#    55106.0,
#    '6514643317.0',
#    'tomdupaul@msn.com',
#    'http://www.visionstree.com/']],
#  [[141416,
#    '1000010135.0',
#    'North Oaks Insurance L.L.C.',
#    '1255 Gun Club Rd',
#    'White Bear Lake',
#    'MN',
#    55110.0,
#    '6519989822.0',
#    'info@northoaksfs.com',
#    'http://www.northoaksfs.com/']],
#  [[141675,
#    '1000010364.0',
#    'Digital Office Centre, Inc',
#    '515 20th Ave SE Ste 11',
#    'Minot',
#    'ND',
#    58701.0,
#    '7018392707.0',
#    'xerox@minot.com',
#    'http://www.docnd.com/']],
#  [[144846,
#    '1000013103.0',
#    'Meulebroeck, Taubert & Co., PLLP',
#    '216 E Main St',
#    'Pipestone',
#    'MN',
#    56164.0,
#    '5078254288.0',
#    'contactp@mtcocpa.com',
#    'http://www.mtcocpa.com/']],
#  [[147686,
#    '1000015515.0',
#    'Design Tile & Flooring Inc',
#    '11786 Quail Rd',
#    'Avon',
#    'MN',
#    56310.0,
#    '3203637220.0',
#    'don@designtileandflooring.com',
#    'http://www.designtileandflooring.com']],
#  [[148629,
#    '1000016258.0',
#    'TC Distributors, LLC',
#    '1977 Geneva Ave N',
#    'Oakdale',
#    'MN',
#    55128.0,
#    '6122980333.0',
#    'tcdistributorsllc@gmail.com',
#    'http://rainbowvacuummn.com']],
#  [[157752,
#    '1000027057.0',
#    'All Seasons Home Improvements LLC',
#    '4948 Kahler Bay NE',
#    'Albertville',
#    'MN',
#    55301.0,
#    '7634585913.0',
#    'jim@allseasonsmn.com',
#    'http://www.allseasonsmn.com']],
#  [[161732,
#    '1000035178.0',
#    'Valvoline, A Division of Ashland Inc',
#    '500 Paul Bunyan Dr. NW',
#    'Bemidji',
#    'MN',
#    56601.0,
#    '6128614499.0',
#    'info@expresscaremn.com',
#    'http://www.vioc.com']],
#  [[161750,
#    '1000035191.0',
#    'Pulte Homes of Minnesota, LLC',
#    '10920 Territorial Trl',
#    'Maple Grove',
#    'MN',
#    55369.0,
#    'nan',
#    'marty.gergen@pultegroup.com',
#    'http://www.centexhomes.com']],
#  [[161752,
#    '1000035193.0',
#    'Pulte Homes of Minnesota, LLC',
#    '14220 56th Ave N',
#    'Plymouth',
#    'MN',
#    55446.0,
#    'nan',
#    'marty.gergen@pultegroup.com',
#    'http://www.centexhomes.com']],
#  [[162348,
#    '1000035799.0',
#    'KinderCare Learning Centers LLC',
#    '8425 City Centre Dr',
#    'Saint Paul',
#    'MN',
#    55125.0,
#    'nan',
#    'care@kindercare.com',
#    'http://www.knowledgebeginnings.com/']],
#  [[162479,
#    '1000035940.0',
#    'Wells Fargo Bank Minnesota',
#    '208 Main Ave N',
#    'Thief River Falls',
#    'MN',
#    56701.0,
#    '2186811130.0',
#    'hansonji@wellsfargo.com',
#    'http://www.wellsfargo.com']],
#  [[162535,
#    '1000035996.0',
#    'Wells Fargo Bank Minnesota',
#    '430 3rd Street',
#    'Dassel',
#    'MN',
#    55325.0,
#    'nan',
#    'hansonji@wellsfargo.com',
#    'http://www.wellsfargo.com']],
#  [[162546,
#    '1000036007.0',
#    'Wells Fargo Bank Minnesota',
#    '5920 Brooklyn Blvd',
#    'Brooklyn Center',
#    'MN',
#    55429.0,
#    '6126672905.0',
#    'hansonji@wellsfargo.com',
#    'http://www.wellsfargo.com']],
#  [[168463,
#    '1000045842.0',
#    'Northwoods  Servicing LLC',
#    '1012 N 5th St',
#    'Minneapolis',
#    'MN',
#    55411.0,
#    'nan',
#    'info@nwsproperties.com',
#    'http://www.nwsproperties.com/']],
#  [[170489,
#    '1000048532.0',
#    "Elk Ridge Alzheimer's Special Care Center",
#    '1700 Beam Ave.',
#    'Maplewood',
#    'MN',
#    55109.0,
#    '6517790500.0',
#    'contact@sinceriseniorliving.com',
#    'https://sinceriseniorliving.com/elk-ridge/']],
#  [[172288,
#    '96114600.0',
#    'Flooring Expo by Carpet King - Maple Grove',
#    '8802 W 35W Service Dr NE',
#    'Blaine',
#    'MN',
#    55449.0,
#    'nan',
#    'marketing@flooringexpo.com',
#    'https://www.youtube.com/watch?v=4mCOLBCpW38']],
#  [[172291,
#    '96114576.0',
#    'Flooring Expo by Carpet King - Ridgedale',
#    '8802 W 35W Service Dr NE',
#    'Blaine',
#    'MN',
#    55449.0,
#    '6122871700.0',
#    'wendygabler@flooringexpo.com',
#    'https://www.youtube.com/watch?v=4mCOLBCpW38']],
#  [[173551,
#    '1000054087.0',
#    'Radon Pros',
#    '522 Fourth Street South ',
#    'Stillwater',
#    'MN',
#    55082.0,
#    '6519272887.0',
#    'info@radonprosmn.com',
#    'http://radonprosmn.com']],
#  [[176313,
#    '1000057576.0',
#    'McKeever Well Drilling',
#    '9436 W Highway 61',
#    'Schroeder',
#    'MN',
#    55613.0,
#    '2186637634.0',
#    'info@mckeeverwelldrilling.com',
#    'http://www.mckeeverwelldrilling.com/']]]

# %%
#Converts record data from a list of records and converts it into a Dataframe
def flattenRecords(record_list) -> pd.DataFrame:
    flattened_data = [item for sublist in record_list[1:] for item in sublist]
    df=pd.DataFrame(flattened_data, columns= ['ID', 'firm_id', 'company_name', 'address', 'city', 'state', 'zip',
                                             'phone', 'email', 'url'])
   # df.drop(['ID','company_name', 'condensed_name', 
   #         'main', 'legal', 'address_1', 'address_2', 'city', 
   #          'state', 'zip', 'zip_4', 'phone', 'email', 'url'],inplace=True,axis=1)
    return df

# %%
def flattenRecords(record_list) -> pd.DataFrame:
    flattened_data = [item for sublist in record_list[1:] for item in sublist]
    df=pd.DataFrame(flattened_data, columns= ['firm_id'])
    df.drop(['condensed_name','main','legal','zip','zip_4'],inplace=True,axis=1)
    return df

# %%
#Uses the above function to convert the list of values from record_data using the IDs from the matches dataframe
df1 = flattenRecords(ID_list1)
df2 = flattenRecords(ID_list2)

# %%
df1
# Out:
#         ID       firm_id                                  company_name  \
# 0    31626    96016442.0                        Boyton Health Services
# 1    53160    96099993.0  Red Wing Housing and Redevelopment Authority
# 2    59684    96123517.0                         Pinnacle Services Inc
# 3    70393    96146766.0                        Talberg Lawn Landscape
# 4    75674    96159974.0            Westside Liquor of Waite Park, Inc
# 5    75700    96160022.0                 Westside Liquor of Rice, Inc.
# 6    82542    96204963.0                Homeopathic Medical Clinic, PA
# 7   106751    96502396.0                         Arend Remodeling, LLC
# 8   110522    96540988.0                            7O2 Communications
# 9   125281    96569281.0                    Forman Market Incorporated
# 10  127010    96572615.0                        Cherry Creek Water LLC
# 11  133137  1000002172.0                           Vision Tree Service
# 12  141416  1000010135.0                   North Oaks Insurance L.L.C.
# 13  141675  1000010364.0                    Digital Office Centre, Inc
# 14  144846  1000013103.0              Meulebroeck, Taubert & Co., PLLP
# 15  147686  1000015515.0                    Design Tile & Flooring Inc
# 16  148629  1000016258.0                          TC Distributors, LLC
# 17  157752  1000027057.0             All Seasons Home Improvements LLC
# 18  161732  1000035178.0          Valvoline, A Division of Ashland Inc
# 19  161750  1000035191.0                 Pulte Homes of Minnesota, LLC
# 20  161752  1000035193.0                 Pulte Homes of Minnesota, LLC
# 21  162348  1000035799.0               KinderCare Learning Centers LLC
# 22  162479  1000035940.0                    Wells Fargo Bank Minnesota
# 23  162535  1000035996.0                    Wells Fargo Bank Minnesota
# 24  162546  1000036007.0                    Wells Fargo Bank Minnesota
# 25  168463  1000045842.0                     Northwoods  Servicing LLC
# 26  170489  1000048532.0     Elk Ridge Alzheimer's Special Care Center
# 27  172288    96114600.0    Flooring Expo by Carpet King - Maple Grove
# 28  172291    96114576.0      Flooring Expo by Carpet King - Ridgedale
# 29  173551  1000054087.0                                    Radon Pros
# 30  176313  1000057576.0                        McKeever Well Drilling
#
#                      address               city state      zip         phone  \
# 0           410 Church St SE        Minneapolis    MN  55455.0  6126258400.0
# 1               428 W 5th St           Red Wing    MN  55066.0  6513850551.0
# 2         724 Central Ave NE        Minneapolis    MN  55414.0  6129773100.0
# 3           11770 Justen Cir              Osseo    MN  55369.0  7634283550.0
# 4           8585 NE River Rd               Rice    MN  56367.0  3202539511.0
# 5           8585 NE River Rd               Rice    MN  56367.0  3203934513.0
# 6        4201 Excelsior Blvd        Minneapolis    MN  55416.0  9529338900.0
# 7            1301 Cannon Ave        Mounds View    MN  55112.0           nan
# 8               702 Main Ave           Moorhead    MN  56560.0  2182275166.0
# 9           108 S Cascade St       Fergus Falls    MN  56537.0  2189984330.0
# 10             502 3rd St NW       Watford City    ND  58854.0  7018426525.0
# 11             895 Ivy Ave E         Saint Paul    MN  55106.0  6514643317.0
# 12          1255 Gun Club Rd    White Bear Lake    MN  55110.0  6519989822.0
# 13    515 20th Ave SE Ste 11              Minot    ND  58701.0  7018392707.0
# 14             216 E Main St          Pipestone    MN  56164.0  5078254288.0
# 15            11786 Quail Rd               Avon    MN  56310.0  3203637220.0
# 16         1977 Geneva Ave N            Oakdale    MN  55128.0  6122980333.0
# 17        4948 Kahler Bay NE        Albertville    MN  55301.0  7634585913.0
# 18    500 Paul Bunyan Dr. NW            Bemidji    MN  56601.0  6128614499.0
# 19     10920 Territorial Trl        Maple Grove    MN  55369.0           nan
# 20          14220 56th Ave N           Plymouth    MN  55446.0           nan
# 21       8425 City Centre Dr         Saint Paul    MN  55125.0           nan
# 22            208 Main Ave N  Thief River Falls    MN  56701.0  2186811130.0
# 23            430 3rd Street             Dassel    MN  55325.0           nan
# 24        5920 Brooklyn Blvd    Brooklyn Center    MN  55429.0  6126672905.0
# 25             1012 N 5th St        Minneapolis    MN  55411.0           nan
# 26            1700 Beam Ave.          Maplewood    MN  55109.0  6517790500.0
# 27  8802 W 35W Service Dr NE             Blaine    MN  55449.0           nan
# 28  8802 W 35W Service Dr NE             Blaine    MN  55449.0  6122871700.0
# 29  522 Fourth Street South          Stillwater    MN  55082.0  6519272887.0
# 30         9436 W Highway 61          Schroeder    MN  55613.0  2186637634.0
#
#                                    email  \
# 0                  canderson@bhs.umn.edu
# 1     randal.hemmerlin@ci.red-wing.mn.us
# 2   nicolas.thomley@pinnacleservices.org
# 3                        nfo@talberg.com
# 4              mholte@westsideliquor.com
# 5              mholte@westsideliquor.com
# 6                  jmirman@demystify.com
# 7                mark.arend@usfamily.net
# 8                         702@702com.net
# 9                   rickell@fintegra.net
# 10                    info@CitadelEP.com
# 11                     tomdupaul@msn.com
# 12                  info@northoaksfs.com
# 13                       xerox@minot.com
# 14                  contactp@mtcocpa.com
# 15         don@designtileandflooring.com
# 16           tcdistributorsllc@gmail.com
# 17                  jim@allseasonsmn.com
# 18                info@expresscaremn.com
# 19           marty.gergen@pultegroup.com
# 20           marty.gergen@pultegroup.com
# 21                   care@kindercare.com
# 22               hansonji@wellsfargo.com
# 23               hansonji@wellsfargo.com
# 24               hansonji@wellsfargo.com
# 25                info@nwsproperties.com
# 26       contact@sinceriseniorliving.com
# 27            marketing@flooringexpo.com
# 28          wendygabler@flooringexpo.com
# 29                  info@radonprosmn.com
# 30         info@mckeeverwelldrilling.com
#
#                                             url
# 0                        http://www.bhs.umn.edu
# 1                     http://www.redwinghra.org
# 2               http://www.pinnacleservices.org
# 3                        http://www.talberg.com
# 4         https://facebook.com/westsideliquormn
# 5         https://facebook.com/westsideliquormn
# 6                  http://www.bookonhealing.com
# 7                http://www.arendremodeling.com
# 8                           https://702com.net/
# 9                     http://www.richardell.com
# 10                     http://www.citadelep.com
# 11                  http://www.visionstree.com/
# 12                  http://www.northoaksfs.com/
# 13                        http://www.docnd.com/
# 14                      http://www.mtcocpa.com/
# 15         http://www.designtileandflooring.com
# 16                   http://rainbowvacuummn.com
# 17                  http://www.allseasonsmn.com
# 18                          http://www.vioc.com
# 19                   http://www.centexhomes.com
# 20                   http://www.centexhomes.com
# 21          http://www.knowledgebeginnings.com/
# 22                    http://www.wellsfargo.com
# 23                    http://www.wellsfargo.com
# 24                    http://www.wellsfargo.com
# 25                http://www.nwsproperties.com/
# 26   https://sinceriseniorliving.com/elk-ridge/
# 27  https://www.youtube.com/watch?v=4mCOLBCpW38
# 28  https://www.youtube.com/watch?v=4mCOLBCpW38
# 29                       http://radonprosmn.com
# 30         http://www.mckeeverwelldrilling.com/

# %%
df2
# Out:
#         ID       firm_id                                company_name  \
# 0    12001    21004636.0                     Boynton Health Services
# 1    53159    96099992.0  Red Wing Housing & Redevelopment Authority
# 2    56086    96112007.0                      Pinnacle Services, Inc
# 3    22224    96000350.0                  Talberg Lawn & Landscaping
# 4    75152    96158896.0            Westside Liquor of Sartell, Inc.
# 5    75152    96158896.0            Westside Liquor of Sartell, Inc.
# 6    80097    96181169.0               Homeopathic Medical Clinic PA
# 7    86209    96249102.0                            Arend Remodeling
# 8    11005    20001775.0                          702 Communications
# 9   125276    96569277.0                  Milnor Market Incorporated
# 10  127006    96572613.0                      Cherry Creek S W D LLC
# 11    8212    11003071.0                        Visions Tree Service
# 12  141415  1000010134.0                    North Oaks Insurance LLC
# 13   69366    96143934.0                   Digital Office Center Inc
# 14  140358  1000009127.0                  Meulebroeck, Taubert, & Co
# 15  138190  1000007231.0                      Design Tile & Flooring
# 16  100240    96369208.0                        TC Distributing, LLC
# 17   85583    96236263.0           All Seasons Home Improvement, LLC
# 18  161730  1000035176.0        Valvoline, A Division of Ashland Inc
# 19  161744  1000035190.0               Pulte Homes of Minnesota, LLC
# 20  161751  1000035192.0               Pulte Homes of Minnesota, LLC
# 21  162347  1000035798.0             KinderCare Learning Centers LLC
# 22  162472  1000035933.0                  Wells Fargo Bank Minnesota
# 23  162427  1000035888.0                  Wells Fargo Bank Minnesota
# 24  162544  1000036005.0                  Wells Fargo Bank Minnesota
# 25  167128  1000044797.0                        Northwoods Servicing
# 26  170320  1000048388.0   Elk Ridge Alzheimer's Special Care Center
# 27  172286    96114504.0   Flooring Expo by Carpet King - Burnsville
# 28  172287    96114546.0        Flooring Expo by Carpet King - Eagan
# 29  173550  1000054086.0                               Radon Pros MN
# 30   83040    96210127.0                   Mc Keever's Well Drilling
#
#                      address             city state      zip         phone  \
# 0           410 Church St SE      Minneapolis    MN  55455.0  6126251434.0
# 1               428 W 5th St         Red Wing    MN  55066.0  6513887571.0
# 2         724 Central Ave NE      Minneapolis    MN  55414.0  6129773100.0
# 3           11770 Justen Cir      Maple Grove    MN  55369.0  7634283550.0
# 4           8585 NE River Rd             Rice    MN  56367.0  3202408866.0
# 5           8585 NE River Rd             Rice    MN  56367.0  3202408866.0
# 6        4201 Excelsior Blvd    St Louis Park    MN  55416.0           nan
# 7            1301 Cannon Ave      Arden Hills    MN  55112.0  6513089756.0
# 8               702 Main Ave         Moorhead    MN  56560.0  8777021118.0
# 9           108 S Cascade St     Fergus Falls    MN  56537.0  2189984330.0
# 10             502 3rd St NW     Watford City    ND  58854.0  7018426525.0
# 11             895 Ivy Ave E       Saint Paul    MN  55106.0  5073883709.0
# 12          1255 Gun Club Rd  White Bear Lake    MN  55110.0  6519989822.0
# 13    515 20th Ave SE Ste 11            Minot    ND  58701.0  7018392707.0
# 14             216 E Main St        Pipestone    MN  56164.0  5078254280.0
# 15            11786 Quail Rd             Avon    MN  56310.0  3207741999.0
# 16         1977 Geneva Ave N          Oakdale    MN  55128.0  6122980323.0
# 17        4948 Kahler Bay NE      Albertville    MN  55301.0  7633893455.0
# 18   1700 Paul Bunyan Dr. NW          Bemidji    MN  56601.0  5076251034.0
# 19     10910 Territorial Trl      Maple Grove    MN  55369.0           nan
# 20          14210 56th Ave N         Plymouth    MN  55446.0           nan
# 21       8400 City Centre Dr       Saint Paul    MN  55125.0           nan
# 22            201 Main Ave N         Baudette    MN  56623.0  2186341252.0
# 23            110 3rd Street          Carlton    MN  55718.0  2183844238.0
# 24        5620 Brooklyn Blvd  Brooklyn Center    MN  55429.0  6123161708.0
# 25             1012 N 5th St      Minneapolis    MN  55411.0  6122639444.0
# 26             1700 Beam Ave        Maplewood    MN  55109.0  6517790500.0
# 27  8802 W 35W Service Dr NE           Blaine    MN  55449.0           nan
# 28  8802 W 35W Service Dr NE           Blaine    MN  55449.0  6122871700.0
# 29  522 Fourth Street South        Stillwater    MN  55082.0  6519272887.0
# 30         9436 W Highway 61        Schroeder    MN  55613.0  2186637634.0
#
#                                    email  \
# 0                  canderson@bhs.umn.edu
# 1     randal.hemmerlin@ci.red-wing.mn.us
# 2   nicolas.thomley@pinnacleservices.org
# 3                       info@talberg.com
# 4              mholte@westsideliquor.com
# 5              mholte@westsideliquor.com
# 6                  jmirman@demystify.com
# 7                mark.arend@usfamily.net
# 8                         702@702com.net
# 9                   rickell@fintegra.net
# 10                    info@CitadelEP.com
# 11                     tomdupaul@msn.com
# 12                  info@northoaksfs.com
# 13                       xerox@minot.com
# 14                  contactp@mtcocpa.com
# 15         kim@designtileandflooring.com
# 16           tcdistributorsllc@gmail.com
# 17                  jim@allseasonsmn.com
# 18                info@expresscaremn.com
# 19           marty.gergen@pultegroup.com
# 20           marty.gergen@pultegroup.com
# 21                   care@kindercare.com
# 22               hansonji@wellsfargo.com
# 23               hansonji@wellsfargo.com
# 24               hansonji@wellsfargo.com
# 25                info@nwsproperties.com
# 26       contact@sinceriseniorliving.com
# 27            marketing@flooringexpo.com
# 28          wendygabler@flooringexpo.com
# 29                  info@radonprosmn.com
# 30         info@McKeeverWellDrilling.com
#
#                                             url
# 0                        http://www.bhs.umn.edu
# 1                     http://www.redwinghra.org
# 2             https://www.pinnacleservices.org/
# 3                       http://www.talberg.com/
# 4         https://facebook.com/westsideliquormn
# 5         https://facebook.com/westsideliquormn
# 6                 http://www.bookonhealing.com/
# 7                    http://arendremodeling.com
# 8                         http://www.702com.com
# 9                     http://www.richardell.com
# 10                     http://www.citadelep.com
# 11                       http://visionstree.com
# 12                  http://www.northoaksfs.com/
# 13                         http://www.docnd.com
# 14                      http://www.mtcocpa.com/
# 15         http://www.designtileandflooring.com
# 16               http://www.rainbowvacuummn.com
# 17                  http://www.allseasonsmn.com
# 18                          http://www.vioc.com
# 19                   http://www.centexhomes.com
# 20                   http://www.centexhomes.com
# 21          http://www.knowledgebeginnings.com/
# 22                    http://www.wellsfargo.com
# 23                    http://www.wellsfargo.com
# 24                    http://www.wellsfargo.com
# 25                 http://Www.nwsproperties.com
# 26   https://sinceriseniorliving.com/elk-ridge/
# 27  https://www.youtube.com/watch?v=4mCOLBCpW38
# 28  https://www.youtube.com/watch?v=4mCOLBCpW38
# 29                       http://radonprosmn.com
# 30          http://www.mckeeverwelldrilling.com
